# %%
# This cell allows you to train the net by exposing it to a bunch of different sequences generated by the system.
keras_history = History()
num_of_runs = 500
losses = []
differences = []
for i in range(num_of_runs):
    training_data = generate_training_data(100000)
    training_inputs = training_data[0]
    training_outputs = training_data[1]
    print(f'Training set {i + 1}/{num_runs} started')
    keras_history = system_model.fit(training_inputs,training_outputs,batch_size=100,epochs=3000,validation_split=0.2)
    loss = keras_history.history["val_loss"]
    losses.append(loss)
    difference = keras_history.history["val_true_difference"]
    differences.append(difference)
    print(f'Training set {i + 1}/{num_runs} completed')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-0abd258bac4f> in <module>()
#       8     training_inputs = training_data[0]
#       9     training_outputs = training_data[1]
# ---> 10     print(f'Training set {i + 1}/{num_runs} started')
#      11     keras_history = system_model.fit(training_inputs,training_outputs,batch_size=100,epochs=3000,validation_split=0.2)
#      12     loss = keras_history.history["val_loss"]
#
# NameError: name 'num_runs' is not defined

# %%
import numpy as np
import random as rand
import tensorflow as tf
import pandas as pd
import keras
import matplotlib
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import SimpleRNN
from keras.layers import Add as keras_add_layers
from keras.callbacks import History
np.set_printoptions(suppress=True)
keras_history = History()

# %%
# Generates training data
def generate_training_data(data_amount=10000):
    max_value = 100000000
    scalar_value = 10
    inputs = []
    outputs = []
    prev_force = 0
    weight = 45
    for i in range(data_amount):
        nums = [scalar_value * rand.randint(-max_value,max_value) / max_value,prev_force]
        inputs.append(np.array(nums))
        prev_force += nums[0] / weight
        outputs.append(np.array([prev_force]))
    return [np.array(inputs),np.array(outputs)]

# %%
def get_progression(model,inputs):
    training_input = inputs[0]
    preds = [inputs[0][1]]
    for i in range(len(inputs)):
        #training_input = [training_input[0] if x == 0 else inputs[i][x - 1] for x in range()]
        training_input = [inputs[i][0],training_input[1]]
        #training_input = [training_input[0],inputs[i][1]]
        output = model.predict(np.array([training_input,training_input]))[0]
        #print(inputs[i])
        #print('----------')
        #print(training_input)
        #print()
        preds.append(output[0])
        training_input[1] = output[0]
        #training_input[0] = output[0]
        #print(f"{i + 1} / {len(inputs)}")
    return np.array(preds)

# %%
# Defines the custom accuracy metric
def true_difference(y_true, y_pred):
    print(y_true)
    return np.abs(y_true - y_pred)

# %%
# Generates a data frame containing training relevant data
training_data = generate_training_data(100000)
training_inputs = training_data[0]
training_outputs = training_data[1]
df = pd.DataFrame(data=[[i,training_inputs[i][0],training_inputs[i][1],training_outputs[i][0]]
                        for i in range(len(training_inputs))],
                  columns=["Time","Displacement","Prev_Force","Force"])
#df

# %%
ax = df.plot(x='Time',y='Force')

# %%
ax2 = df.plot(x='Time',y='Displacement')

# %%
# Create model
system_model = Sequential()
#system_model.add(SimpleRNN(2,activation="linear"))
system_model.add(Dense(4,activation="linear",input_dim=2))
#system_model.add(Dropout(0.12))
system_model.add(Dense(6,activation="sigmoid"))
#system_model.add(Dropout(0.12))
system_model.add(Dense(1,activation="linear"))
system_model.compile(optimizer="adam",loss="mean_absolute_percentage_error",metrics=['mae'])

# %%
keras_history = system_model.fit(training_inputs,training_outputs,batch_size=256,epochs=2000)
# Out:
# Epoch 1/2000
# 100000/100000 [==============================] - 0s 3us/step - loss: 1.9467 - mean_absolute_error: 0.1411
# Epoch 2/2000
# 100000/100000 [==============================] - 0s 3us/step - loss: 1.4525 - mean_absolute_error: 0.1284
# Epoch 3/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3919 - mean_absolute_error: 0.1442
# Epoch 4/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4629 - mean_absolute_error: 0.1412
# Epoch 5/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4334 - mean_absolute_error: 0.1327
# Epoch 6/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3801 - mean_absolute_error: 0.1243
# Epoch 7/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4849 - mean_absolute_error: 0.1319
# Epoch 8/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4724 - mean_absolute_error: 0.1374
# Epoch 9/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4151 - mean_absolute_error: 0.1311
# Epoch 10/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4619 - mean_absolute_error: 0.1308
# Epoch 11/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4502 - mean_absolute_error: 0.1457
# Epoch 12/2000
# 100000/100000 [==============================] - 0s 3us/step - loss: 1.4692 - mean_absolute_error: 0.1487
# Epoch 13/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0722 - mean_absolute_error: 0.1214
# Epoch 14/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1697 - mean_absolute_error: 0.1267
# Epoch 15/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 2.0157 - mean_absolute_error: 0.1337
# Epoch 16/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4494 - mean_absolute_error: 0.1396
# Epoch 17/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4310 - mean_absolute_error: 0.1341
# Epoch 18/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7373 - mean_absolute_error: 0.1168
# Epoch 19/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 2.2710 - mean_absolute_error: 0.1611
# Epoch 20/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7422 - mean_absolute_error: 0.1211
# Epoch 21/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 2.3915 - mean_absolute_error: 0.1432
# Epoch 22/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4105 - mean_absolute_error: 0.1345
# Epoch 23/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4235 - mean_absolute_error: 0.1325
# Epoch 24/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3479 - mean_absolute_error: 0.1318
# Epoch 25/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8934 - mean_absolute_error: 0.1274
# Epoch 26/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.9244 - mean_absolute_error: 0.1385
# Epoch 27/2000
# 100000/100000 [==============================] - 0s 3us/step - loss: 1.4250 - mean_absolute_error: 0.1415
# Epoch 28/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4701 - mean_absolute_error: 0.1269
# Epoch 29/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3185 - mean_absolute_error: 0.1218
# Epoch 30/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4118 - mean_absolute_error: 0.1282
# Epoch 31/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.5209 - mean_absolute_error: 0.1499
# Epoch 32/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3326 - mean_absolute_error: 0.1216
# Epoch 33/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4074 - mean_absolute_error: 0.1286
# Epoch 34/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2877 - mean_absolute_error: 0.1380
# Epoch 35/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.5509 - mean_absolute_error: 0.1236
# Epoch 36/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3634 - mean_absolute_error: 0.1296
# Epoch 37/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4412 - mean_absolute_error: 0.1296
# Epoch 38/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2172 - mean_absolute_error: 0.1186
# Epoch 39/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3485 - mean_absolute_error: 0.1318
# Epoch 40/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.5869 - mean_absolute_error: 0.1385
# Epoch 41/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4523 - mean_absolute_error: 0.1298
# Epoch 42/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.6968 - mean_absolute_error: 0.1176
# Epoch 43/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 2.2535 - mean_absolute_error: 0.1460
# Epoch 44/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3161 - mean_absolute_error: 0.1270
# Epoch 45/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2882 - mean_absolute_error: 0.1257
# Epoch 46/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3576 - mean_absolute_error: 0.1200
# Epoch 47/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4326 - mean_absolute_error: 0.1310
# Epoch 48/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4150 - mean_absolute_error: 0.1321
# Epoch 49/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7013 - mean_absolute_error: 0.1084
# Epoch 50/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 2.0463 - mean_absolute_error: 0.1500
# Epoch 51/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0229 - mean_absolute_error: 0.1221
# Epoch 52/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.6293 - mean_absolute_error: 0.1449
# Epoch 53/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3239 - mean_absolute_error: 0.1191
# Epoch 54/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3676 - mean_absolute_error: 0.1290
# Epoch 55/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3765 - mean_absolute_error: 0.1291
# Epoch 56/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.6610 - mean_absolute_error: 0.1065
# Epoch 57/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 2.0439 - mean_absolute_error: 0.1448
# Epoch 58/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3379 - mean_absolute_error: 0.1255
# Epoch 59/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4151 - mean_absolute_error: 0.1346
# Epoch 60/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2864 - mean_absolute_error: 0.1230
# Epoch 61/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3584 - mean_absolute_error: 0.1267
# Epoch 62/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2786 - mean_absolute_error: 0.1339
# Epoch 63/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.5360 - mean_absolute_error: 0.1226
# Epoch 64/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2954 - mean_absolute_error: 0.1278
# Epoch 65/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2673 - mean_absolute_error: 0.1306
# Epoch 66/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2572 - mean_absolute_error: 0.1184
# Epoch 67/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4813 - mean_absolute_error: 0.1312
# Epoch 68/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3175 - mean_absolute_error: 0.1261
# Epoch 69/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0391 - mean_absolute_error: 0.1238
# Epoch 70/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.5178 - mean_absolute_error: 0.1236
# Epoch 71/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3539 - mean_absolute_error: 0.1207
# Epoch 72/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.5217 - mean_absolute_error: 0.1394
# Epoch 73/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1751 - mean_absolute_error: 0.1197
# Epoch 74/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4374 - mean_absolute_error: 0.1191
# Epoch 75/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1451 - mean_absolute_error: 0.1115
# Epoch 76/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3356 - mean_absolute_error: 0.1263
# Epoch 77/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3706 - mean_absolute_error: 0.1230
# Epoch 78/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3039 - mean_absolute_error: 0.1247
# Epoch 79/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3834 - mean_absolute_error: 0.1282
# Epoch 80/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3944 - mean_absolute_error: 0.1168
# Epoch 81/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2613 - mean_absolute_error: 0.1174
# Epoch 82/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3379 - mean_absolute_error: 0.1254
# Epoch 83/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3096 - mean_absolute_error: 0.1225
# Epoch 84/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3070 - mean_absolute_error: 0.1235
# Epoch 85/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2147 - mean_absolute_error: 0.1133
# Epoch 86/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2732 - mean_absolute_error: 0.1166
# Epoch 87/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9563 - mean_absolute_error: 0.1219
# Epoch 88/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.7374 - mean_absolute_error: 0.1235
# Epoch 89/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3463 - mean_absolute_error: 0.1355
# Epoch 90/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3270 - mean_absolute_error: 0.1282
# Epoch 91/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3430 - mean_absolute_error: 0.1274
# Epoch 92/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3084 - mean_absolute_error: 0.1274
# Epoch 93/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1783 - mean_absolute_error: 0.1202
# Epoch 94/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3286 - mean_absolute_error: 0.1164
# Epoch 95/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.6699 - mean_absolute_error: 0.1009
# Epoch 96/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 2.2124 - mean_absolute_error: 0.1612
# Epoch 97/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3256 - mean_absolute_error: 0.1229
# Epoch 98/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1835 - mean_absolute_error: 0.1150
# Epoch 99/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3180 - mean_absolute_error: 0.1382
# Epoch 100/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2341 - mean_absolute_error: 0.1201
# Epoch 101/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7231 - mean_absolute_error: 0.1114
# Epoch 102/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.8784 - mean_absolute_error: 0.1232
# Epoch 103/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3464 - mean_absolute_error: 0.1230
# Epoch 104/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1399 - mean_absolute_error: 0.1401
# Epoch 105/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.6459 - mean_absolute_error: 0.1238
# Epoch 106/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3701 - mean_absolute_error: 0.1383
# Epoch 107/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1495 - mean_absolute_error: 0.1166
# Epoch 108/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3425 - mean_absolute_error: 0.1132
# Epoch 109/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2310 - mean_absolute_error: 0.1256
# Epoch 110/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2759 - mean_absolute_error: 0.1257
# Epoch 111/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2899 - mean_absolute_error: 0.1201
# Epoch 112/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2876 - mean_absolute_error: 0.1222
# Epoch 113/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2821 - mean_absolute_error: 0.1127
# Epoch 114/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7467 - mean_absolute_error: 0.1187
# Epoch 115/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.8803 - mean_absolute_error: 0.1323
# Epoch 116/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2127 - mean_absolute_error: 0.1132
# Epoch 117/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3302 - mean_absolute_error: 0.1269
# Epoch 118/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2936 - mean_absolute_error: 0.1187
# Epoch 119/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3086 - mean_absolute_error: 0.1288
# Epoch 120/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1455 - mean_absolute_error: 0.1174
# Epoch 121/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1662 - mean_absolute_error: 0.1188
# Epoch 122/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2567 - mean_absolute_error: 0.1164
# Epoch 123/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.5014 - mean_absolute_error: 0.1276
# Epoch 124/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3520 - mean_absolute_error: 0.1216
# Epoch 125/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2210 - mean_absolute_error: 0.1262
# Epoch 126/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2294 - mean_absolute_error: 0.1157
# Epoch 127/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3159 - mean_absolute_error: 0.1252
# Epoch 128/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1735 - mean_absolute_error: 0.1137
# Epoch 129/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2509 - mean_absolute_error: 0.1209
# Epoch 130/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2418 - mean_absolute_error: 0.1132
# Epoch 131/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0084 - mean_absolute_error: 0.1179
# Epoch 132/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3110 - mean_absolute_error: 0.1229
# Epoch 133/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4672 - mean_absolute_error: 0.1180
# Epoch 134/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.5880 - mean_absolute_error: 0.0998
# Epoch 135/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.8055 - mean_absolute_error: 0.1478
# Epoch 136/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2275 - mean_absolute_error: 0.1202
# Epoch 137/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0984 - mean_absolute_error: 0.1128
# Epoch 138/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7459 - mean_absolute_error: 0.1101
# Epoch 139/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.8110 - mean_absolute_error: 0.1168
# Epoch 140/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2109 - mean_absolute_error: 0.1259
# Epoch 141/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2189 - mean_absolute_error: 0.1146
# Epoch 142/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2439 - mean_absolute_error: 0.1132
# Epoch 143/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1930 - mean_absolute_error: 0.1177
# Epoch 144/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2621 - mean_absolute_error: 0.1171
# Epoch 145/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0380 - mean_absolute_error: 0.1130
# Epoch 146/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1324 - mean_absolute_error: 0.1230
# Epoch 147/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.6606 - mean_absolute_error: 0.0931
# Epoch 148/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.6420 - mean_absolute_error: 0.1366
# Epoch 149/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2769 - mean_absolute_error: 0.1317
# Epoch 150/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.5817 - mean_absolute_error: 0.1195
# Epoch 151/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2418 - mean_absolute_error: 0.1172
# Epoch 152/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.5659 - mean_absolute_error: 0.1044
# Epoch 153/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.8468 - mean_absolute_error: 0.1337
# Epoch 154/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1526 - mean_absolute_error: 0.1190
# Epoch 155/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2998 - mean_absolute_error: 0.1189
# Epoch 156/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2305 - mean_absolute_error: 0.1163
# Epoch 157/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7800 - mean_absolute_error: 0.1090
# Epoch 158/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.5377 - mean_absolute_error: 0.1236
# Epoch 159/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1424 - mean_absolute_error: 0.1117
# Epoch 160/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2350 - mean_absolute_error: 0.1147
# Epoch 161/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1699 - mean_absolute_error: 0.1163
# Epoch 162/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2517 - mean_absolute_error: 0.1240
# Epoch 163/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2311 - mean_absolute_error: 0.1197
# Epoch 164/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1541 - mean_absolute_error: 0.1138
# Epoch 165/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2299 - mean_absolute_error: 0.1316
# Epoch 166/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2304 - mean_absolute_error: 0.1115
# Epoch 167/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2188 - mean_absolute_error: 0.1130
# Epoch 168/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1803 - mean_absolute_error: 0.1234
# Epoch 169/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9838 - mean_absolute_error: 0.1101
# Epoch 170/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2313 - mean_absolute_error: 0.1176
# Epoch 171/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9445 - mean_absolute_error: 0.1117
# Epoch 172/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.6109 - mean_absolute_error: 0.1276
# Epoch 173/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0084 - mean_absolute_error: 0.1114
# Epoch 174/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3872 - mean_absolute_error: 0.1129
# Epoch 175/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.6496 - mean_absolute_error: 0.1046
# Epoch 176/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.7609 - mean_absolute_error: 0.1414
# Epoch 177/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2941 - mean_absolute_error: 0.1266
# Epoch 178/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.5483 - mean_absolute_error: 0.0943
# Epoch 179/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.8328 - mean_absolute_error: 0.1413
# Epoch 180/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7084 - mean_absolute_error: 0.1131
# Epoch 181/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.6926 - mean_absolute_error: 0.1332
# Epoch 182/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.4853 - mean_absolute_error: 0.0900
# Epoch 183/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.8640 - mean_absolute_error: 0.1419
# Epoch 184/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8396 - mean_absolute_error: 0.1149
# Epoch 185/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4522 - mean_absolute_error: 0.1106
# Epoch 186/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1771 - mean_absolute_error: 0.1139
# Epoch 187/2000
# 100000/100000 [==============================] - 0s 3us/step - loss: 1.0006 - mean_absolute_error: 0.1303
# Epoch 188/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4287 - mean_absolute_error: 0.1199
# Epoch 189/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9246 - mean_absolute_error: 0.1159
# Epoch 190/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3515 - mean_absolute_error: 0.1173
# Epoch 191/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1658 - mean_absolute_error: 0.1074
# Epoch 192/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1182 - mean_absolute_error: 0.1132
# Epoch 193/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1440 - mean_absolute_error: 0.1159
# Epoch 194/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0985 - mean_absolute_error: 0.1081
# Epoch 195/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9402 - mean_absolute_error: 0.1153
# Epoch 196/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3420 - mean_absolute_error: 0.1151
# Epoch 197/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0946 - mean_absolute_error: 0.1177
# Epoch 198/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1892 - mean_absolute_error: 0.1191
# Epoch 199/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1097 - mean_absolute_error: 0.1102
# Epoch 200/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.5610 - mean_absolute_error: 0.0826
# Epoch 201/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.9286 - mean_absolute_error: 0.1500
# Epoch 202/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0982 - mean_absolute_error: 0.1181
# Epoch 203/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7967 - mean_absolute_error: 0.1154
# Epoch 204/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.5229 - mean_absolute_error: 0.1134
# Epoch 205/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0482 - mean_absolute_error: 0.1077
# Epoch 206/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0874 - mean_absolute_error: 0.1150
# Epoch 207/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1641 - mean_absolute_error: 0.1160
# Epoch 208/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1538 - mean_absolute_error: 0.1204
# Epoch 209/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.6778 - mean_absolute_error: 0.0961
# Epoch 210/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.5892 - mean_absolute_error: 0.1267
# Epoch 211/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2248 - mean_absolute_error: 0.1299
# Epoch 212/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1599 - mean_absolute_error: 0.1124
# Epoch 213/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9275 - mean_absolute_error: 0.1032
# Epoch 214/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2388 - mean_absolute_error: 0.1131
# Epoch 215/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0702 - mean_absolute_error: 0.1160
# Epoch 216/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2190 - mean_absolute_error: 0.1114
# Epoch 217/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2621 - mean_absolute_error: 0.1175
# Epoch 218/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8100 - mean_absolute_error: 0.1154
# Epoch 219/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.5060 - mean_absolute_error: 0.1187
# Epoch 220/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1620 - mean_absolute_error: 0.1124
# Epoch 221/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1213 - mean_absolute_error: 0.1136
# Epoch 222/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1096 - mean_absolute_error: 0.1119
# Epoch 223/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1418 - mean_absolute_error: 0.1142
# Epoch 224/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1330 - mean_absolute_error: 0.1205
# Epoch 225/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1305 - mean_absolute_error: 0.1229
# Epoch 226/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1868 - mean_absolute_error: 0.1181
# Epoch 227/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1071 - mean_absolute_error: 0.1029
# Epoch 228/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1568 - mean_absolute_error: 0.1244
# Epoch 229/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1341 - mean_absolute_error: 0.1154
# Epoch 230/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1062 - mean_absolute_error: 0.1153
# Epoch 231/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1168 - mean_absolute_error: 0.1130
# Epoch 232/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1553 - mean_absolute_error: 0.1282
# Epoch 233/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1526 - mean_absolute_error: 0.1190
# Epoch 234/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1079 - mean_absolute_error: 0.1103
# Epoch 235/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1076 - mean_absolute_error: 0.1180
# Epoch 236/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7336 - mean_absolute_error: 0.1052
# Epoch 237/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4953 - mean_absolute_error: 0.1186
# Epoch 238/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1222 - mean_absolute_error: 0.1134
# Epoch 239/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0816 - mean_absolute_error: 0.1249
# Epoch 240/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1503 - mean_absolute_error: 0.1150
# Epoch 241/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0934 - mean_absolute_error: 0.1132
# Epoch 242/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1396 - mean_absolute_error: 0.1141
# Epoch 243/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2835 - mean_absolute_error: 0.1219
# Epoch 244/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0809 - mean_absolute_error: 0.1121
# Epoch 245/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0926 - mean_absolute_error: 0.1205
# Epoch 246/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9808 - mean_absolute_error: 0.1057
# Epoch 247/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1655 - mean_absolute_error: 0.1247
# Epoch 248/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.4806 - mean_absolute_error: 0.0862
# Epoch 249/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.9927 - mean_absolute_error: 0.1610
# Epoch 250/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9218 - mean_absolute_error: 0.1150
# Epoch 251/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2761 - mean_absolute_error: 0.1132
# Epoch 252/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9669 - mean_absolute_error: 0.1123
# Epoch 253/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2956 - mean_absolute_error: 0.1080
# Epoch 254/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1002 - mean_absolute_error: 0.1133
# Epoch 255/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.6521 - mean_absolute_error: 0.1111
# Epoch 256/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.6679 - mean_absolute_error: 0.1275
# Epoch 257/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1179 - mean_absolute_error: 0.1269
# Epoch 258/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.5669 - mean_absolute_error: 0.0846
# Epoch 259/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.7979 - mean_absolute_error: 0.1519
# Epoch 260/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0049 - mean_absolute_error: 0.1158
# Epoch 261/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7028 - mean_absolute_error: 0.0866
# Epoch 262/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.5745 - mean_absolute_error: 0.1569
# Epoch 263/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1369 - mean_absolute_error: 0.1097
# Epoch 264/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0705 - mean_absolute_error: 0.1120
# Epoch 265/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0308 - mean_absolute_error: 0.1123
# Epoch 266/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8434 - mean_absolute_error: 0.1091
# Epoch 267/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3272 - mean_absolute_error: 0.1283
# Epoch 268/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0641 - mean_absolute_error: 0.1068
# Epoch 269/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1598 - mean_absolute_error: 0.1196
# Epoch 270/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1767 - mean_absolute_error: 0.1192
# Epoch 271/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9913 - mean_absolute_error: 0.1067
# Epoch 272/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1045 - mean_absolute_error: 0.1150
# Epoch 273/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0883 - mean_absolute_error: 0.1121
# Epoch 274/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9731 - mean_absolute_error: 0.1159
# Epoch 275/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2003 - mean_absolute_error: 0.1241
# Epoch 276/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0053 - mean_absolute_error: 0.1098
# Epoch 277/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0720 - mean_absolute_error: 0.1199
# Epoch 278/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1065 - mean_absolute_error: 0.1207
# Epoch 279/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1414 - mean_absolute_error: 0.1189
# Epoch 280/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.5510 - mean_absolute_error: 0.0945
# Epoch 281/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.6940 - mean_absolute_error: 0.1301
# Epoch 282/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9923 - mean_absolute_error: 0.1234
# Epoch 283/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2001 - mean_absolute_error: 0.1105
# Epoch 284/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7034 - mean_absolute_error: 0.1122
# Epoch 285/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.5277 - mean_absolute_error: 0.1322
# Epoch 286/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0359 - mean_absolute_error: 0.1113
# Epoch 287/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1498 - mean_absolute_error: 0.1118
# Epoch 288/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1099 - mean_absolute_error: 0.1108
# Epoch 289/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0838 - mean_absolute_error: 0.1107
# Epoch 290/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8337 - mean_absolute_error: 0.1069
# Epoch 291/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3353 - mean_absolute_error: 0.1138
# Epoch 292/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1247 - mean_absolute_error: 0.1234
# Epoch 293/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0783 - mean_absolute_error: 0.1064
# Epoch 294/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1173 - mean_absolute_error: 0.1178
# Epoch 295/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0939 - mean_absolute_error: 0.1189
# Epoch 296/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0774 - mean_absolute_error: 0.1325
# Epoch 297/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9622 - mean_absolute_error: 0.1155
# Epoch 298/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2347 - mean_absolute_error: 0.1177
# Epoch 299/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0584 - mean_absolute_error: 0.1071
# Epoch 300/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7191 - mean_absolute_error: 0.1103
# Epoch 301/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.6028 - mean_absolute_error: 0.1194
# Epoch 302/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0204 - mean_absolute_error: 0.1186
# Epoch 303/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2463 - mean_absolute_error: 0.1087
# Epoch 304/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0707 - mean_absolute_error: 0.1167
# Epoch 305/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9606 - mean_absolute_error: 0.1163
# Epoch 306/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2232 - mean_absolute_error: 0.1068
# Epoch 307/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0884 - mean_absolute_error: 0.1187
# Epoch 308/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9487 - mean_absolute_error: 0.1193
# Epoch 309/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2049 - mean_absolute_error: 0.1085
# Epoch 310/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0338 - mean_absolute_error: 0.1085
# Epoch 311/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.6522 - mean_absolute_error: 0.0987
# Epoch 312/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.6412 - mean_absolute_error: 0.1118
# Epoch 313/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0031 - mean_absolute_error: 0.1036
# Epoch 314/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1193 - mean_absolute_error: 0.1159
# Epoch 315/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0994 - mean_absolute_error: 0.1179
# Epoch 316/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1127 - mean_absolute_error: 0.1079
# Epoch 317/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0118 - mean_absolute_error: 0.1098
# Epoch 318/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1048 - mean_absolute_error: 0.1172
# Epoch 319/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1053 - mean_absolute_error: 0.1070
# Epoch 320/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0465 - mean_absolute_error: 0.1053
# Epoch 321/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1134 - mean_absolute_error: 0.1110
# Epoch 322/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0909 - mean_absolute_error: 0.1156
# Epoch 323/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1373 - mean_absolute_error: 0.1242
# Epoch 324/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1301 - mean_absolute_error: 0.1417
# Epoch 325/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9748 - mean_absolute_error: 0.1051
# Epoch 326/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0799 - mean_absolute_error: 0.1131
# Epoch 327/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0609 - mean_absolute_error: 0.1107
# Epoch 328/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0517 - mean_absolute_error: 0.1069
# Epoch 329/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0639 - mean_absolute_error: 0.1220
# Epoch 330/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0193 - mean_absolute_error: 0.1172
# Epoch 331/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2084 - mean_absolute_error: 0.1075
# Epoch 332/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0345 - mean_absolute_error: 0.1164
# Epoch 333/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.4903 - mean_absolute_error: 0.0839
# Epoch 334/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.6886 - mean_absolute_error: 0.1452
# Epoch 335/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0495 - mean_absolute_error: 0.1148
# Epoch 336/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1538 - mean_absolute_error: 0.1170
# Epoch 337/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0077 - mean_absolute_error: 0.1105
# Epoch 338/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0415 - mean_absolute_error: 0.1047
# Epoch 339/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1711 - mean_absolute_error: 0.1268
# Epoch 340/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9897 - mean_absolute_error: 0.1081
# Epoch 341/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1212 - mean_absolute_error: 0.1063
# Epoch 342/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.6942 - mean_absolute_error: 0.1079
# Epoch 343/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4963 - mean_absolute_error: 0.1216
# Epoch 344/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.5573 - mean_absolute_error: 0.0935
# Epoch 345/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4587 - mean_absolute_error: 0.1449
# Epoch 346/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0494 - mean_absolute_error: 0.1259
# Epoch 347/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0949 - mean_absolute_error: 0.1158
# Epoch 348/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9904 - mean_absolute_error: 0.1044
# Epoch 349/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1230 - mean_absolute_error: 0.1341
# Epoch 350/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0119 - mean_absolute_error: 0.1129
# Epoch 351/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0422 - mean_absolute_error: 0.1066
# Epoch 352/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9049 - mean_absolute_error: 0.1110
# Epoch 353/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3944 - mean_absolute_error: 0.1226
# Epoch 354/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0337 - mean_absolute_error: 0.1122
# Epoch 355/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9972 - mean_absolute_error: 0.0988
# Epoch 356/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.6776 - mean_absolute_error: 0.1048
# Epoch 357/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4202 - mean_absolute_error: 0.1243
# Epoch 358/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0499 - mean_absolute_error: 0.1312
# Epoch 359/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0994 - mean_absolute_error: 0.1243
# Epoch 360/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0540 - mean_absolute_error: 0.1043
# Epoch 361/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0785 - mean_absolute_error: 0.1203
# Epoch 362/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9778 - mean_absolute_error: 0.1209
# Epoch 363/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0233 - mean_absolute_error: 0.1085
# Epoch 364/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9110 - mean_absolute_error: 0.1090
# Epoch 365/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1757 - mean_absolute_error: 0.1206
# Epoch 366/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9447 - mean_absolute_error: 0.1085
# Epoch 367/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0442 - mean_absolute_error: 0.1178
# Epoch 368/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1658 - mean_absolute_error: 0.1230
# Epoch 369/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8742 - mean_absolute_error: 0.1078
# Epoch 370/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0404 - mean_absolute_error: 0.1091
# Epoch 371/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2752 - mean_absolute_error: 0.1173
# Epoch 372/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9962 - mean_absolute_error: 0.1114
# Epoch 373/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0515 - mean_absolute_error: 0.1106
# Epoch 374/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0681 - mean_absolute_error: 0.1132
# Epoch 375/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0758 - mean_absolute_error: 0.1256
# Epoch 376/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0206 - mean_absolute_error: 0.1009
# Epoch 377/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0095 - mean_absolute_error: 0.1078
# Epoch 378/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0324 - mean_absolute_error: 0.1099
# Epoch 379/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9473 - mean_absolute_error: 0.0981
# Epoch 380/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9663 - mean_absolute_error: 0.1029
# Epoch 381/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0269 - mean_absolute_error: 0.1090
# Epoch 382/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1009 - mean_absolute_error: 0.1267
# Epoch 383/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0007 - mean_absolute_error: 0.1058
# Epoch 384/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9921 - mean_absolute_error: 0.1295
# Epoch 385/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2632 - mean_absolute_error: 0.1188
# Epoch 386/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.5176 - mean_absolute_error: 0.0920
# Epoch 387/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 2.0871 - mean_absolute_error: 0.1691
# Epoch 388/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0027 - mean_absolute_error: 0.1075
# Epoch 389/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8863 - mean_absolute_error: 0.0947
# Epoch 390/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9799 - mean_absolute_error: 0.1177
# Epoch 391/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0197 - mean_absolute_error: 0.1092
# Epoch 392/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0156 - mean_absolute_error: 0.1249
# Epoch 393/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0348 - mean_absolute_error: 0.1158
# Epoch 394/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1078 - mean_absolute_error: 0.1119
# Epoch 395/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9097 - mean_absolute_error: 0.1148
# Epoch 396/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.3076 - mean_absolute_error: 0.1246
# Epoch 397/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9966 - mean_absolute_error: 0.1159
# Epoch 398/2000
# ...
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7952 - mean_absolute_error: 0.1288
# Epoch 1095/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9761 - mean_absolute_error: 0.0877
# Epoch 1096/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.6453 - mean_absolute_error: 0.0984
# Epoch 1097/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0448 - mean_absolute_error: 0.0960
# Epoch 1098/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7990 - mean_absolute_error: 0.0886
# Epoch 1099/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8905 - mean_absolute_error: 0.1047
# Epoch 1100/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8560 - mean_absolute_error: 0.1042
# Epoch 1101/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8426 - mean_absolute_error: 0.0953
# Epoch 1102/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8699 - mean_absolute_error: 0.1002
# Epoch 1103/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8257 - mean_absolute_error: 0.0967
# Epoch 1104/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8950 - mean_absolute_error: 0.1141
# Epoch 1105/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8242 - mean_absolute_error: 0.0951
# Epoch 1106/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8173 - mean_absolute_error: 0.0958
# Epoch 1107/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8506 - mean_absolute_error: 0.0978
# Epoch 1108/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.5707 - mean_absolute_error: 0.0956
# Epoch 1109/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9841 - mean_absolute_error: 0.0910
# Epoch 1110/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8556 - mean_absolute_error: 0.1057
# Epoch 1111/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8750 - mean_absolute_error: 0.1123
# Epoch 1112/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8439 - mean_absolute_error: 0.0964
# Epoch 1113/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7501 - mean_absolute_error: 0.0946
# Epoch 1114/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.6636 - mean_absolute_error: 0.0915
# Epoch 1115/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0484 - mean_absolute_error: 0.0949
# Epoch 1116/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8253 - mean_absolute_error: 0.1062
# Epoch 1117/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8417 - mean_absolute_error: 0.0886
# Epoch 1118/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8379 - mean_absolute_error: 0.1011
# Epoch 1119/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8304 - mean_absolute_error: 0.0932
# Epoch 1120/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9155 - mean_absolute_error: 0.1082
# Epoch 1121/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.5506 - mean_absolute_error: 0.0941
# Epoch 1122/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1597 - mean_absolute_error: 0.0918
# Epoch 1123/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7375 - mean_absolute_error: 0.0980
# Epoch 1124/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9749 - mean_absolute_error: 0.1192
# Epoch 1125/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7681 - mean_absolute_error: 0.0965
# Epoch 1126/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8703 - mean_absolute_error: 0.0902
# Epoch 1127/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8127 - mean_absolute_error: 0.0917
# Epoch 1128/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8881 - mean_absolute_error: 0.1094
# Epoch 1129/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8312 - mean_absolute_error: 0.0866
# Epoch 1130/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8926 - mean_absolute_error: 0.1092
# Epoch 1131/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8331 - mean_absolute_error: 0.0993
# Epoch 1132/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.4322 - mean_absolute_error: 0.0852
# Epoch 1133/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.4495 - mean_absolute_error: 0.1303
# Epoch 1134/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8012 - mean_absolute_error: 0.0939
# Epoch 1135/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8500 - mean_absolute_error: 0.1026
# Epoch 1136/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8147 - mean_absolute_error: 0.0936
# Epoch 1137/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7826 - mean_absolute_error: 0.0884
# Epoch 1138/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7987 - mean_absolute_error: 0.1005
# Epoch 1139/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8577 - mean_absolute_error: 0.0889
# Epoch 1140/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8564 - mean_absolute_error: 0.0937
# Epoch 1141/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8692 - mean_absolute_error: 0.0985
# Epoch 1142/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8848 - mean_absolute_error: 0.1133
# Epoch 1143/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.6957 - mean_absolute_error: 0.0994
# Epoch 1144/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9643 - mean_absolute_error: 0.1044
# Epoch 1145/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9771 - mean_absolute_error: 0.0999
# Epoch 1146/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7559 - mean_absolute_error: 0.0857
# Epoch 1147/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7809 - mean_absolute_error: 0.0951
# Epoch 1148/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9559 - mean_absolute_error: 0.0998
# Epoch 1149/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8491 - mean_absolute_error: 0.0856
# Epoch 1150/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8301 - mean_absolute_error: 0.1000
# Epoch 1151/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9453 - mean_absolute_error: 0.0949
# Epoch 1152/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8703 - mean_absolute_error: 0.0923
# Epoch 1153/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7826 - mean_absolute_error: 0.0964
# Epoch 1154/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8514 - mean_absolute_error: 0.1026
# Epoch 1155/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8273 - mean_absolute_error: 0.1045
# Epoch 1156/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.6286 - mean_absolute_error: 0.1027
# Epoch 1157/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1276 - mean_absolute_error: 0.1010
# Epoch 1158/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7512 - mean_absolute_error: 0.0996
# Epoch 1159/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8652 - mean_absolute_error: 0.0992
# Epoch 1160/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8226 - mean_absolute_error: 0.1005
# Epoch 1161/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9062 - mean_absolute_error: 0.1067
# Epoch 1162/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8275 - mean_absolute_error: 0.0955
# Epoch 1163/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8604 - mean_absolute_error: 0.0949
# Epoch 1164/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9186 - mean_absolute_error: 0.1056
# Epoch 1165/2000
# 100000/100000 [==============================] - 0s 3us/step - loss: 0.5044 - mean_absolute_error: 0.0804
# Epoch 1166/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0498 - mean_absolute_error: 0.1266
# Epoch 1167/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0254 - mean_absolute_error: 0.0883
# Epoch 1168/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8184 - mean_absolute_error: 0.0999
# Epoch 1169/2000
# 100000/100000 [==============================] - 0s 3us/step - loss: 0.8653 - mean_absolute_error: 0.0966
# Epoch 1170/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7802 - mean_absolute_error: 0.0995
# Epoch 1171/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8951 - mean_absolute_error: 0.1034
# Epoch 1172/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8016 - mean_absolute_error: 0.1014
# Epoch 1173/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7892 - mean_absolute_error: 0.0949
# Epoch 1174/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0182 - mean_absolute_error: 0.1074
# Epoch 1175/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8338 - mean_absolute_error: 0.0864
# Epoch 1176/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8147 - mean_absolute_error: 0.1066
# Epoch 1177/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8702 - mean_absolute_error: 0.1080
# Epoch 1178/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8536 - mean_absolute_error: 0.0956
# Epoch 1179/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.3600 - mean_absolute_error: 0.0697
# Epoch 1180/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.1964 - mean_absolute_error: 0.1273
# Epoch 1181/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.0960 - mean_absolute_error: 0.0903
# Epoch 1182/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8704 - mean_absolute_error: 0.1041
# Epoch 1183/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7823 - mean_absolute_error: 0.0990
# Epoch 1184/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8137 - mean_absolute_error: 0.1036
# Epoch 1185/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8969 - mean_absolute_error: 0.1032
# Epoch 1186/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8417 - mean_absolute_error: 0.0986
# Epoch 1187/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7801 - mean_absolute_error: 0.0917
# Epoch 1188/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8231 - mean_absolute_error: 0.0908
# Epoch 1189/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.6007 - mean_absolute_error: 0.0918
# Epoch 1190/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 1.2268 - mean_absolute_error: 0.1063
# Epoch 1191/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8369 - mean_absolute_error: 0.0973
# Epoch 1192/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7736 - mean_absolute_error: 0.0908
# Epoch 1193/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8950 - mean_absolute_error: 0.0897
# Epoch 1194/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.8751 - mean_absolute_error: 0.1023
# Epoch 1195/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7459 - mean_absolute_error: 0.0983
# Epoch 1196/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9296 - mean_absolute_error: 0.0890
# Epoch 1197/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.7388 - mean_absolute_error: 0.1000
# Epoch 1198/2000
# 100000/100000 [==============================] - 0s 2us/step - loss: 0.9956 - mean_absolute_error: 0.1083
# Epoch 1199/2000
#  22272/100000 [=====>........................] - ETA: 0s - loss: 0.4384 - mean_absolute_error: 0.1147
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-c0bf058f6f79> in <module>()
# ----> 1 keras_history = system_model.fit(training_inputs,training_outputs,batch_size=256,epochs=2000)
#
# c:\users\max9613\appdata\local\programs\python\python36\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1035                                         initial_epoch=initial_epoch,
#    1036                                         steps_per_epoch=steps_per_epoch,
# -> 1037                                         validation_steps=validation_steps)
#    1038
#    1039     def evaluate(self, x=None, y=None,
#
# c:\users\max9613\appdata\local\programs\python\python36\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     202                     batch_logs[l] = o
#     203
# --> 204                 callbacks.on_batch_end(batch_index, batch_logs)
#     205                 if callback_model.stop_training:
#     206                     break
#
# c:\users\max9613\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks.py in on_batch_end(self, batch, logs)
#     113             callback.on_batch_end(batch, logs)
#     114         self._delta_ts_batch_end.append(time.time() - t_before_callbacks)
# --> 115         delta_t_median = np.median(self._delta_ts_batch_end)
#     116         if (self._delta_t_batch > 0. and
#     117            (delta_t_median > 0.95 * self._delta_t_batch and delta_t_median > 0.1)):
#
# c:\users\max9613\appdata\local\programs\python\python36\lib\site-packages\numpy\lib\function_base.py in median(a, axis, out, overwrite_input, keepdims)
#    4117     """
#    4118     r, k = _ureduce(a, func=_median, axis=axis, out=out,
# -> 4119                     overwrite_input=overwrite_input)
#    4120     if keepdims:
#    4121         return r.reshape(k)
#
# c:\users\max9613\appdata\local\programs\python\python36\lib\site-packages\numpy\lib\function_base.py in _ureduce(a, func, **kwargs)
#    4031         keepdim = (1,) * a.ndim
#    4032
# -> 4033     r = func(a, **kwargs)
#    4034     return r, keepdim
#    4035
#
# c:\users\max9613\appdata\local\programs\python\python36\lib\site-packages\numpy\lib\function_base.py in _median(a, axis, out, overwrite_input)
#    4150             part = a
#    4151     else:
# -> 4152         part = partition(a, kth, axis=axis)
#    4153
#    4154     if part.shape == ():
#
# c:\users\max9613\appdata\local\programs\python\python36\lib\site-packages\numpy\core\fromnumeric.py in partition(a, kth, axis, kind, order)
#     662     else:
#     663         a = asanyarray(a).copy(order="K")
# --> 664     a.partition(kth, axis=axis, kind=kind, order=order)
#     665     return a
#     666
#
# KeyboardInterrupt:

# %%
loss = keras_history.history['loss']
val_loss = keras_history.history['val_loss']
history_df = pd.DataFrame(data=[[i,loss[i],val_loss[i]] for i in range(len(keras_history.history["loss"]))],
                         columns=["Time","Loss","Val_Loss"])
#history_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-7c1345df488c> in <module>()
#       1 loss = keras_history.history['loss']
# ----> 2 val_loss = keras_history.history['val_loss']
#       3 history_df = pd.DataFrame(data=[[i,loss[i],val_loss[i]] for i in range(len(keras_history.history["loss"]))],
#       4                          columns=["Time","Loss","Val_Loss"])
#       5 #history_df
#
# KeyError: 'val_loss'

# %%
ax = history_df.plot(x='Time',y=['Loss','Val_Loss'])

# %%
preds_1 = system_model.predict(training_inputs)
preds_2 = get_progression(system_model,training_inputs)
df2 = pd.DataFrame(data=[[i,preds_1[i][0],preds_2[i],training_outputs[i][0],
                          np.abs(preds_1[i][0] - training_outputs[i][0]) / ((preds_1[i][0] + training_outputs[i][0]) / 2),
                          np.abs(preds_2[i] - training_outputs[i][0]) / ((preds_2[i] + training_outputs[i][0]) / 2)] 
                          for i in range(len(training_outputs))],
                          columns=['Time','Predictions_1','Predictions_2','Real','Difference','Difference_2'])
#df2

# %%
ax = df2.plot(x='Time',y='Real',ylim=(min(training_outputs) - 2,max(training_outputs) + 2))

# %%
ax = df2.plot(x='Time',y='Predictions_1',ylim=(min(training_outputs) - 2,max(training_outputs) + 2))

# %%
ax = df2.plot(x='Time',y='Predictions_2',ylim=(min(training_outputs) - 2,max(training_outputs) + 2))

# %%
ax = df2.plot(x='Time',y='Difference_2',ylim=(-10,10))

# %%
ax = df2.plot(x='Time',y='Difference',ylim=(-10,10))

# %%
new_training_data = generate_training_data()
new_training_inputs = new_training_data[0]
new_training_outputs = new_training_data[1]
new_preds_1 = system_model.predict(new_training_inputs)
new_preds_2 = get_progression(system_model,new_training_inputs)
df3 = pd.DataFrame(data=[[i,new_preds_1[i][0],new_preds_2[i],new_training_outputs[i][0],
                          np.abs(new_preds_1[i][0] - new_training_outputs[i][0]) / ((new_preds_1[i][0] + new_training_outputs[i][0]) / 2),
                          np.abs(new_preds_2[i] - new_training_outputs[i][0]) / ((new_preds_2[i] + new_training_outputs[i][0]) / 2)] 
                          for i in range(len(new_training_outputs))],
                          columns=['Time','Predictions_1','Predictions_2','Real','Difference_1','Difference_2'])
#df3

# %%
ax = df3.plot(x='Time',y='Real',ylim=(min(new_training_outputs) - 2,max(new_training_outputs) + 2))

# %%
ax = df3.plot(x='Time',y='Predictions_1',ylim=(min(new_training_outputs) - 2,max(new_training_outputs) + 2))

# %%
#ax = df3.plot(x='Time',y='Predictions_2',c='Difference_2',colormap='viridis',ylim=(min(new_training_outputs) - 2,max(new_training_outputs) + 2))
ax = df3.plot(x='Time',y='Predictions_2',ylim=(min(new_training_outputs) - 2,max(new_training_outputs) + 2))

# %%
ax = df3.plot(x='Time',y='Difference_2',ylim=(-10,10))

# %%
ax = df3.plot(x='Time',y='Difference_1',ylim=(-10,10))
